# %% [markdown]
# # DMQC Report: WMO 4901134
#
# ## Current status and metadata:
#
# - APEX float in Pacific Ocean
# - Deployed in February 2010, inactive since July 2012
# - Completed 91 cycles over 2.5 years
# - Core files in D-mode, oxygen in A-mode adjusted by Henry Bittig

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt
import seaborn as sns

from netCDF4 import Dataset

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4901134 # insert WMO number here
fig_path = Path('../../../figures/') / f'{wmo}' # where to save figures
fig_path.mkdir(exist_ok=True)
bgc.io.get_argo(wmo, local_path=bgc.io.Path.ARGO_PATH) # download the data to ensure you have up to date files
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA') # calculate gain, can change to ref='NCEP' if in-air data is available
print(np.nanmean(gains))

# check what/if anything is done already
nc = Dataset(flt.__Sprof__)
print(bgc.io.read_ncstr(nc['SCIENTIFIC_CALIB_COMMENT'][:][50,-1,3,:]))
print(nc['DOXY_ADJUSTED'][:][-1,:]/nc['DOXY'][:][-1,:])
nc.close()
# Out:
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\4901134_Rtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\4901134_Sprof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\4901134_meta.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\4901134_prof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\4901134_tech.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_001.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_002.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_003.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_004.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_005.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_006.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_007.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_008.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_009.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_010.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_011.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_012.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_013.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_014.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_015.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_016.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_017.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_018.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_019.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_020.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_021.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_022.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_023.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_024.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_025.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_026.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_027.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_028.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_029.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_030.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_031.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_032.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_033.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_034.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_035.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_036.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_037.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_038.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_039.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_040.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_041.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_042.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_043.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_044.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_045.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_046.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_047.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_048.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_049.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_050.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_051.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_052.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_053.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_054.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_055.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_056.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_057.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_058.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_059.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_060.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_061.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_062.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_063.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_064.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_065.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_066.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_067.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_068.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_069.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_070.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_071.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_072.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_073.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_074.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_075.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_076.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_077.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_078.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_079.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_080.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_081.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_082.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_083.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_084.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_085.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_086.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_087.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_088.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_089.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\D4901134_091.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_001.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_002.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_003.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_004.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_005.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_006.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_007.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_008.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_009.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_010.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_011.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_012.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_013.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_014.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_015.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_016.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_017.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_018.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_019.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_020.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_021.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_022.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_023.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_024.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_025.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_026.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_027.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_028.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_029.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_030.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_031.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_032.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_033.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_034.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_035.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_036.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_037.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_038.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_039.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_040.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_041.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_042.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_043.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_044.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_045.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_046.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_047.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_048.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_049.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_050.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_051.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_052.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_053.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_054.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_055.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_056.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_057.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_058.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_059.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_060.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_061.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_062.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_063.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_064.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_065.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_066.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_067.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_068.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_069.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_070.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_071.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_072.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_073.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_074.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_075.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_076.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_077.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_078.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_079.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_080.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_081.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_082.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_083.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_084.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_085.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_086.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_087.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_088.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_089.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901134\profiles\SD4901134_091.nc
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.117817134791763
# by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 21 slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma
# [1.0850077867507935 1.085007667541504 1.085007667541504 1.085007667541504
#  1.0850077867507935 1.085007667541504 1.0850077867507935
#  1.0850077867507935 1.0850077867507935 1.085007667541504
#  1.0850077867507935 1.0850077867507935 1.085007667541504
#  1.0850077867507935 1.085007667541504 1.085007667541504 1.0850077867507935
#  1.0850077867507935 1.0850077867507935 1.0850077867507935
#  1.0850077867507935 1.0850077867507935 1.0850077867507935
#  1.0850077867507935 1.0850077867507935 1.085007667541504 1.085007667541504
#  1.0850077867507935 1.0850077867507935 1.085007667541504 1.085007667541504
#  1.0850077867507935 1.0850077867507935 1.0850077867507935
#  1.0850077867507935 1.0850077867507935 1.085007667541504 1.085007667541504
#  1.0850075483322144 1.0850075483322144 1.0850075483322144
#  1.0850074291229248 1.0850073099136353 1.085007905960083
#  1.0850080251693726 1.0850074291229248 1.0850080251693726
#  1.085007905960083 -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- --]

# %% [markdown]
# ## DOXY Audit Status
#
# - If the float has any profiles present in the DOXY audit, which are they are why?
# - Likely will usually be left empty/deleted

# %%
audit_file = list(Path('../../../audit/').glob('DOXY_WOA*'))[-1]
df = pd.read_csv(audit_file, sep='\t', header=25)
df = df.loc[df.WMO == wmo]
df['date'] = [datestr2num(t) for t in df['profile date']]
print(df['WOA G_raw'].mean())
# Out:
# nan

# %% [markdown]
# ## Visual QC
#
# - Visualize the float and reference surface saturations, as well as the profiles.
# - Observe if DOXY data is set to '3' as it should be or if it is '1' or '2'.
# - Try to note cycles or other identifying features of potentially problematic profiles.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_initial.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars, if applicable) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes: [notes on what this figure tells you here]

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.fig.savefig(fig_path / 'qcprofiles.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((205, -5))
g.fig.savefig(fig_path / 'qcprofiles_shallow.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: [notes on what this figure tells you here]

# %% [markdown]
# ## Flag bad data, recalculate gain
#
# - Using the plots above (and likely some more specific plots, made on a case-by-case basis), flag bad DOXY data as 4.
# - After flagging bad data, re-clean the data and re-calculate the gains.

# %%
flt.reset(hard=True)
bad_oxygen = []
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
G = np.nanmean(new_gains)
print(G)

flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
flt.update_field('DOXY_ADJUSTED_ERROR', bgc.calc_fixed_doxy_adjusted_error(flt.PSAL, flt.TEMP, flt.PRES))
# Out:
# Warning: hard resetting back to original file values. Any changes from update_field() or set_fillvalue() will be lost.
# Updating DOXY_QC on 0 levels
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.117817134791763
# Updating DOXY_ADJUSTED_QC on 0 levels
# Updating DOXY_ADJUSTED_ERROR on all levels

# %% [markdown]
# Figure x: Repeated gain plot with bad data removed.
#
# ## Update Fields and Export
#
# - DOXY should be 3 by default, but many old floats have 1 or 0. Though it will be redundant in some cases, make sure DOXY_QC is not good.
# - Apply the gain to calculate DOXY_ADJUSTED.
# - Fill in DOXY_ADJUSTED_ERROR with an appropriate fixed value.
# - Fill in DOXY_ADJUSTED_QC.
# - Make sure DOXY_ADJUSTED and DOXY_ADJUSTED_ERROR are `FillValue` wherever DOXY_ADJUSTED_QC is bad.
# - Export the D-mode files. During export, HISTORY parameters will be filled as well as SCIENTIFIC_CALIB parameters using some default structures and user info set by calling `bgc.configure.configure()`.

# %%
# make sure DOXY_QC is 3 instead of 0,1,2
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC.isin([0, 1, 2]))
# fill in DOXY_ADJUSTED_QC appropriately
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.TEMP_ADJUSTED_QC == 4)
flt.update_field('DOXY_ADJUSTED_QC', 3, where=flt.PSAL_ADJUSTED_QC == 4)
# make sure the data is FillValues where adjusted values are still bad
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.DOXY_ADJUSTED.isna())
flt.set_fillvalue('DOXY_ADJUSTED', where=flt.DOXY_ADJUSTED_QC == 4)
flt.set_fillvalue('DOXY_ADJUSTED_ERROR', where=flt.DOXY_ADJUSTED_QC == 4)

flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[1].set_xlim(g.axes[0].get_xlim())
g.fig.savefig(fig_path / 'qcprofiles_postqc.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((205, -5))
g.fig.savefig(fig_path / 'qcprofiles_shallow_postqc.png', bbox_inches='tight', dpi=250)

flt.clean()
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_final.png', bbox_inches='tight', dpi=250)
# Out:
# Updating DOXY_QC on 5438 levels
# Updating DOXY_ADJUSTED_QC on 3 levels
# Updating DOXY_ADJUSTED_QC on 8 levels
# Updating DOXY_ADJUSTED_QC on 1042 levels
# Updating DOXY_ADJUSTED on 1042 levels
# Updating DOXY_ADJUSTED_ERROR on 1042 levels

# %%
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((1100, 900))
g.axes[0].set_xlim((-1, 21))
g.axes[1].set_xlim((-1, 21))
g.fig.savefig(fig_path / 'qcprofiles_1000m_postqc.png', bbox_inches='tight', dpi=250)

print(flt.df.loc[(flt.df.PRES > 900) & (flt.df.PRES < 1100), 'DOXY'])

fig, ax = plt.subplots()
sns.scatterplot(data=flt.df, x='DOXY', y='PRES', hue='CYCLE', ax=ax, legend=False)
ax.set_ylim((2050, -50))
fig.savefig(fig_path / 'profiles_cycle_scatter.png', bbox_inches='tight', dpi=250)

fig, ax = plt.subplots()
sns.scatterplot(data=flt.df, x='DOXY', y='PRES', hue='CYCLE', ax=ax, legend=False)
ax.set_ylim((1350, 750))
ax.set_xlim((8, 17.5))
fig.savefig(fig_path / 'profiles_cycle_scatter_zoom.png', bbox_inches='tight', dpi=250)
# Out:
# 48      11.731984
# 49      11.810353
# 50      11.904435
# 51      11.990871
# 120     11.690421
#           ...
# 6385    12.054977
# 6386    12.114743
# 6387    12.119408
# 6454    12.053177
# 6455    12.108468
# Name: DOXY, Length: 306, dtype: float32

# %%
# export the files
comment = 'by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma'
comment += f"; Visual QC by Christopher Gordon (DFO, ORCID {bgc.config['orcid']})"
comment = comment.replace('No time response correction done;', '')
flt.export_files(data_mode='D', comment=comment, coeff='previous', equation='previous')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_045.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_071.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_080.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_082.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_083.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_084.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_085.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_086.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_087.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_088.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_089.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_091.nc...done

# %%
# export the files
comment = 'by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma'
comment += f"; Visual QC by Christopher Gordon (DFO, ORCID {bgc.config['orcid']})"
comment = comment.replace('No time response correction done;', '')
flt.export_files(data_mode='D', comment=comment, coeff='previous', equation='previous')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_045.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_071.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_080.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_082.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_083.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_084.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_085.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_086.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_087.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_088.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_089.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901134/profiles/BD4901134_091.nc...done

# %%
# from pathlib import Path
# import pandas as pd
# from netCDF4 import Dataset
# import copy

# wmo = 4900874
# loc = Path(f'/Users/GordonC/Documents/data/Argo/dac/meds/D/{wmo}/profiles/')
# files = pd.read_csv(Path(f'../../../checker/summary/{wmo}/files.txt'))
# varname = 'DOXY'
# for fn in files.files:
#     print(fn)
#     nc = Dataset(loc / fn, 'r+')
#     print(nc['DOXY'][:])
#     flags = copy.deepcopy(nc[varname+'_QC'][:])
#     flags[nc[varname][:].mask] = b'9'
#     nc[varname+'_QC'][:] = flags
#     if varname == 'DOXY':
#         flags = copy.deepcopy(nc[varname+'_ADJUSTED_QC'][:])
#         flags[nc[varname][:].mask] = b'9'
#         nc[varname+'_ADJUSTED_QC'][:] = flags
#     profile = copy.deepcopy(nc['PROFILE_DOXY_QC'][:])
#     profile[0] = b'A'
#     nc['PROFILE_DOXY_QC'][:] = profile
#     nc.close()
