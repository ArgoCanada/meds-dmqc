# %% [markdown]
# # DMQC Report: WMO 4901790
#
# ## Current status and metadata:
#
# - MetOcean NOVA float in the Pacific Ocean
# - July 2015 - October 2018
# - Completed 107 cycles in just under 3 years
# - No in-air data (NOVA float)
# - Physical data in D-mode, DOXY in R-mode
# - Mean WOA gain of 1.118

# %%
import warnings
warnings.filterwarnings('ignore')

import sys
# travel laptop hacky solution for importing bgcArgoDMQC
sys.path.append('\\Users\\GordonC\\Documents\\projects\\bgcArgoDMQC\\')

from pathlib import Path

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt

from netCDF4 import Dataset

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4901790 # insert WMO number here
fig_path = Path('../../../figures/') / f'{wmo}' # where to save figures
fig_path.mkdir(exist_ok=True)
bgc.io.get_argo(wmo, local_path=bgc.io.Path.ARGO_PATH) # download the data to ensure you have up to date files
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA') # calculate gain, can change to ref='NCEP' if in-air data is available
print(np.nanmean(gains))

# check what/if anything is done already
nc = Dataset(Path(flt.__Sprof__).absolute())
print(bgc.io.read_ncstr(nc['SCIENTIFIC_CALIB_COMMENT'][:][50,-1,3,:]))
print(nc['DOXY_ADJUSTED'][:][-1,:]/nc['DOXY'][:][-1,:])
nc.close()
# Out:
# \Users\GordonC\Documents\data\Argo\meds\4901790\4901790_BRtraj.nc
# \Users\GordonC\Documents\data\Argo\meds\4901790\4901790_Rtraj.nc
# \Users\GordonC\Documents\data\Argo\meds\4901790\4901790_Sprof.nc
# \Users\GordonC\Documents\data\Argo\meds\4901790\4901790_meta.nc
# \Users\GordonC\Documents\data\Argo\meds\4901790\4901790_prof.nc
# \Users\GordonC\Documents\data\Argo\meds\4901790\4901790_tech.nc
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.1176633270679526
#
# [-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- --]

# %% [markdown]
# ## DOXY Audit Status
#
# - If the float has any profiles present in the DOXY audit, which are they are why?
# - Likely will usually be left empty/deleted

# %%
audit_file = list(Path('../../../audit/').glob('DOXY_WOA*'))[-1]
df = pd.read_csv(audit_file, sep='\t', header=25)
df = df.loc[df.WMO == wmo]
df['date'] = [datestr2num(t) for t in df['profile date']]
print(df['WOA G_raw'].mean())
# Out:
# nan

# %% [markdown]
# ## Visual QC
#
# - Visualize the float and reference surface saturations, as well as the profiles.
# - Observe if DOXY data is set to '3' as it should be or if it is '1' or '2'.
# - Try to note cycles or other identifying features of potentially problematic profiles.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_initial.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars, if applicable) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes: [notes on what this figure tells you here]

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.fig.savefig(fig_path / 'qcprofiles.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((2000, 1250))
g.axes[0].set_xlim((0, 260))
g.axes[2].set_xlim((0, 110))
g.fig.savefig(fig_path / 'qcprofiles_shallow.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: [notes on what this figure tells you here]

# %% [markdown]
# ## Flag bad data, recalculate gain
#
# - Using the plots above (and likely some more specific plots, made on a case-by-case basis), flag bad DOXY data as 4.
# - After flagging bad data, re-clean the data and re-calculate the gains.

# %%
flt.reset()
bad_oxygen = []
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
G = np.nanmean(new_gains)
print(G)

flt.update_field('DOXY_ADJUSTED', G*flt.DOXY)
flt.update_field('DOXY_ADJUSTED_QC', flt.DOXY_QC)
flt.update_field('DOXY_ADJUSTED_QC', 1, where=flt.DOXY_QC == 3)
flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
flt.update_field('DOXY_ADJUSTED_ERROR', bgc.calc_fixed_doxy_adjusted_error(flt.PSAL, flt.TEMP, flt.PRES))
# Out:
# Updating DOXY_QC on 0 levels
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.1176633270679526
# Updating DOXY_ADJUSTED on all levels
# Updating DOXY_ADJUSTED_QC on all levels
# Updating DOXY_ADJUSTED_QC on 56400 levels
# Updating DOXY_ADJUSTED_QC on 0 levels
# Updating DOXY_ADJUSTED_ERROR on all levels

# %% [markdown]
# Figure x: Repeated gain plot with bad data removed.
#
# ## Update Fields and Export
#
# - DOXY should be 3 by default, but many old floats have 1 or 0. Though it will be redundant in some cases, make sure DOXY_QC is not good.
# - Apply the gain to calculate DOXY_ADJUSTED.
# - Fill in DOXY_ADJUSTED_ERROR with an appropriate fixed value.
# - Fill in DOXY_ADJUSTED_QC.
# - Make sure DOXY_ADJUSTED and DOXY_ADJUSTED_ERROR are `FillValue` wherever DOXY_ADJUSTED_QC is bad.
# - Export the D-mode files. During export, HISTORY parameters will be filled as well as SCIENTIFIC_CALIB parameters using some default structures and user info set by calling `bgc.configure.configure()`.

# %%
# make sure DOXY_QC is 3 instead of 0,1,2
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC.isin([0, 1, 2]))
# fill in DOXY_ADJUSTED_QC appropriately
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.TEMP_ADJUSTED_QC == 4)
flt.update_field('DOXY_ADJUSTED_QC', 3, where=flt.PSAL_ADJUSTED_QC == 4)
# make sure the data is FillValues where adjusted values are still bad
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.DOXY_ADJUSTED.isna())
flt.set_fillvalue('DOXY_ADJUSTED', where=flt.DOXY_ADJUSTED_QC == 4)
flt.set_fillvalue('DOXY_ADJUSTED_ERROR', where=flt.DOXY_ADJUSTED_QC == 4)

flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[1].set_xlim(g.axes[0].get_xlim())
g.fig.savefig(fig_path / 'qcprofiles_postqc.png', bbox_inches='tight', dpi=250)

flt.clean()
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_final.png', bbox_inches='tight', dpi=250)
# Out:
# Updating DOXY_QC on 0 levels
# Updating DOXY_ADJUSTED_QC on 6 levels
# Updating DOXY_ADJUSTED_QC on 45 levels
# Updating DOXY_ADJUSTED_QC on 840 levels
# Updating DOXY_ADJUSTED on 840 levels
# Updating DOXY_ADJUSTED_ERROR on 840 levels

# %%
# export the files - for R to D mode
flt.export_files(data_mode='D')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_000.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_045.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_071.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_080.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_082.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_083.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_084.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_085.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_086.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_087.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_088.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_089.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_090.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_091.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_092.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_093.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_094.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_095.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_096.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_097.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_098.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_099.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_100.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_101.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_102.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_103.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_104.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_105.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_106.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/meds/4901790/profiles/BD4901790_107.nc...done
