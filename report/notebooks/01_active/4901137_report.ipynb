# %% [markdown]
# # DMQC Report: WMO 4901137
#
# ## Current status and metadata:
#
# - APEX float in Pacific Ocean
# - Deployed in August 2010, inactive since September 2012
# - Completed 83 cycles over 2.5 years
# - Core files in D-mode, Oxygen in A-mode adjusted by Henry Bittig

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt
import seaborn as sns

from netCDF4 import Dataset

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4901137 # insert WMO number here
fig_path = Path('../../../figures/') / f'{wmo}' # where to save figures
fig_path.mkdir(exist_ok=True)
bgc.io.get_argo(wmo, local_path=bgc.io.Path.ARGO_PATH) # download the data to ensure you have up to date files
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA') # calculate gain, can change to ref='NCEP' if in-air data is available
print(np.nanmean(gains))

# check what/if anything is done already
nc = Dataset(flt.__Sprof__)
print(bgc.io.read_ncstr(nc['SCIENTIFIC_CALIB_COMMENT'][:][50,-1,3,:]))
print(nc['DOXY_ADJUSTED'][:][-1,:]/nc['DOXY'][:][-1,:])
nc.close()
# Out:
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\4901137_Rtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\4901137_Sprof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\4901137_meta.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\4901137_prof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\4901137_tech.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_001.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_002.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_003.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_004.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_005.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_006.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_007.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_008.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_009.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_010.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_011.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_012.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_013.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_014.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_015.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_016.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_017.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_018.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_019.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_020.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_021.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_022.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_023.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_024.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_025.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_026.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_027.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_028.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_029.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_030.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_031.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_032.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_033.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_034.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_035.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_036.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_037.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_038.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_039.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_040.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_041.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_042.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_043.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_044.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_045.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_046.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_047.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_048.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_049.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_050.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_051.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_052.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_053.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_054.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_055.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_056.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_057.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_058.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_059.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_060.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_061.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_062.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_063.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_064.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_065.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_066.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_067.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_068.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_069.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_070.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_071.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_072.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_073.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_074.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_075.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_076.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_077.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_078.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_079.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_080.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_081.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_082.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_083.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_084.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_085.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_086.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_087.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_088.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_089.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_090.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_091.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_092.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_093.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_094.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_095.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_096.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_097.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_098.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_099.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_100.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_101.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_102.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_103.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_104.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_105.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_106.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_107.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_108.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_109.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_110.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_111.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_112.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_113.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_114.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_115.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_116.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_117.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_118.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_119.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\D4901137_120.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_001.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_002.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_003.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_004.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_005.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_006.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_007.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_008.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_009.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_010.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_011.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_012.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_013.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_014.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_015.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_016.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_017.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_018.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_019.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_020.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_021.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_022.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_023.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_024.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_025.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_026.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_027.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_028.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_029.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_030.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_031.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_032.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_033.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_034.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_035.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_036.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_037.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_038.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_039.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_040.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_041.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_042.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_043.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_044.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_045.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_046.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_047.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_048.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_049.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_050.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_051.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_052.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_053.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_054.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_055.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_056.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_057.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_058.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_059.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_060.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_061.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_062.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_063.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_064.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_065.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_066.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_067.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_068.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_069.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_070.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_071.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_072.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_073.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_074.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_075.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_076.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_077.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_078.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_079.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_080.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_081.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_082.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_083.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_084.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_085.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_086.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_087.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_088.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_089.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_090.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_091.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_092.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_093.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_094.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_095.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_096.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_097.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_098.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_099.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_100.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_101.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_102.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_103.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_104.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_105.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_106.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_107.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_108.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_109.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_110.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_111.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_112.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_113.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_114.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_115.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_116.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_117.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_118.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_119.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901137\profiles\SD4901137_120.nc
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
# Bounding climatological profile(s) missing data - taking simple average of available data.
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.1111314596024329
# G obtained from DOXY audit on 2020-11-20
# [1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 1.1080000400543213
#  1.1080000400543213 1.1080000400543213 --]

# %% [markdown]
# ## DOXY Audit Status
#
# - If the float has any profiles present in the DOXY audit, which are they are why?
# - Likely will usually be left empty/deleted

# %%
audit_file = list(Path('../../../audit/').glob('DOXY_WOA*'))[-1]
df = pd.read_csv(audit_file, sep='\t', header=25)
df = df.loc[df.WMO == wmo]
df['date'] = [datestr2num(t) for t in df['profile date']]
print(df['WOA G_raw'].mean())
# Out:
# nan

# %% [markdown]
# ## Visual QC
#
# - Visualize the float and reference surface saturations, as well as the profiles.
# - Observe if DOXY data is set to '3' as it should be or if it is '1' or '2'.
# - Try to note cycles or other identifying features of potentially problematic profiles.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_initial.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars, if applicable) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes: [notes on what this figure tells you here]

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.fig.savefig(fig_path / 'qcprofiles.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((205, -5))
g.fig.savefig(fig_path / 'qcprofiles_shallow.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: [notes on what this figure tells you here]

# %% [markdown]
# ## Flag bad data, recalculate gain
#
# - Using the plots above (and likely some more specific plots, made on a case-by-case basis), flag bad DOXY data as 4.
# - After flagging bad data, re-clean the data and re-calculate the gains.

# %%
flt.reset(hard=True)
bad_oxygen = []
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
G = np.nanmean(new_gains)
print(G)

flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
flt.update_field('DOXY_ADJUSTED_ERROR', bgc.calc_fixed_doxy_adjusted_error(flt.PSAL, flt.TEMP, flt.PRES))
# Out:
# Warning: hard resetting back to original file values. Any changes from update_field() or set_fillvalue() will be lost.
# Updating DOXY_QC on 0 levels
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.1111314596024329
# Updating DOXY_ADJUSTED_QC on 0 levels
# Updating DOXY_ADJUSTED_ERROR on all levels

# %% [markdown]
# Figure x: Repeated gain plot with bad data removed.
#
# ## Update Fields and Export
#
# - DOXY should be 3 by default, but many old floats have 1 or 0. Though it will be redundant in some cases, make sure DOXY_QC is not good.
# - Apply the gain to calculate DOXY_ADJUSTED.
# - Fill in DOXY_ADJUSTED_ERROR with an appropriate fixed value.
# - Fill in DOXY_ADJUSTED_QC.
# - Make sure DOXY_ADJUSTED and DOXY_ADJUSTED_ERROR are `FillValue` wherever DOXY_ADJUSTED_QC is bad.
# - Export the D-mode files. During export, HISTORY parameters will be filled as well as SCIENTIFIC_CALIB parameters using some default structures and user info set by calling `bgc.configure.configure()`.

# %%
# make sure DOXY_QC is 3 instead of 0,1,2
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC.isin([0, 1, 2]))
# fill in DOXY_ADJUSTED_QC appropriately
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.TEMP_ADJUSTED_QC == 4)
flt.update_field('DOXY_ADJUSTED_QC', 3, where=flt.PSAL_ADJUSTED_QC == 4)
# make sure the data is FillValues where adjusted values are still bad
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.DOXY_ADJUSTED.isna())
flt.set_fillvalue('DOXY_ADJUSTED', where=flt.DOXY_ADJUSTED_QC == 4)
flt.set_fillvalue('DOXY_ADJUSTED_ERROR', where=flt.DOXY_ADJUSTED_QC == 4)

flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[1].set_xlim(g.axes[0].get_xlim())
g.fig.savefig(fig_path / 'qcprofiles_postqc.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((205, -5))
g.fig.savefig(fig_path / 'qcprofiles_shallow_postqc.png', bbox_inches='tight', dpi=250)

flt.clean()
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_final.png', bbox_inches='tight', dpi=250)
# Out:
# Updating DOXY_QC on 7385 levels
# Updating DOXY_ADJUSTED_QC on 0 levels
# Updating DOXY_ADJUSTED_QC on 4 levels
# Updating DOXY_ADJUSTED_QC on 1251 levels
# Updating DOXY_ADJUSTED on 1251 levels
# Updating DOXY_ADJUSTED_ERROR on 1251 levels

# %%
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((1100, 900))
g.axes[0].set_xlim((-1, 21))
g.axes[1].set_xlim((-1, 21))
g.fig.savefig(fig_path / 'qcprofiles_1000m_postqc.png', bbox_inches='tight', dpi=250)

print(flt.df.loc[(flt.df.PRES > 900) & (flt.df.PRES < 1100), 'DOXY'])

fig, ax = plt.subplots()
sns.scatterplot(data=flt.df, x='DOXY', y='PRES', hue='CYCLE', ax=ax, legend=False)
ax.set_ylim((2050, -50))
fig.savefig(fig_path / 'profiles_cycle_scatter.png', bbox_inches='tight', dpi=250)

fig, ax = plt.subplots()
sns.scatterplot(data=flt.df, x='DOXY', y='PRES', hue='CYCLE', ax=ax, legend=False)
ax.set_ylim((1350, 750))
ax.set_xlim((2, 17.5))
fig.savefig(fig_path / 'profiles_cycle_scatter_zoom.png', bbox_inches='tight', dpi=250)
# Out:
# 48      7.604944
# 49      6.722245
# 50      6.998881
# 51      7.114612
# 120     6.828176
#           ...
# 8616    5.706644
# 8617    6.322657
# 8618    7.122342
# 8619    7.783319
# 8620    8.832732
# Name: DOXY, Length: 411, dtype: float32

# %%
# export the files
comment = 'by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma'
comment += f"; Visual QC by Christopher Gordon (DFO, ORCID {bgc.config['orcid']})"
comment = comment.replace('No time response correction done;', '')
flt.export_files(data_mode='D', comment=comment, coeff='previous', equation='previous')

# %%
# from pathlib import Path
# import pandas as pd
# from netCDF4 import Dataset
# import copy

# wmo = 4900874
# loc = Path(f'/Users/GordonC/Documents/data/Argo/dac/meds/D/{wmo}/profiles/')
# files = pd.read_csv(Path(f'../../../checker/summary/{wmo}/files.txt'))
# varname = 'DOXY'
# for fn in files.files:
#     print(fn)
#     nc = Dataset(loc / fn, 'r+')
#     print(nc['DOXY'][:])
#     flags = copy.deepcopy(nc[varname+'_QC'][:])
#     flags[nc[varname][:].mask] = b'9'
#     nc[varname+'_QC'][:] = flags
#     if varname == 'DOXY':
#         flags = copy.deepcopy(nc[varname+'_ADJUSTED_QC'][:])
#         flags[nc[varname][:].mask] = b'9'
#         nc[varname+'_ADJUSTED_QC'][:] = flags
#     profile = copy.deepcopy(nc['PROFILE_DOXY_QC'][:])
#     profile[0] = b'A'
#     nc['PROFILE_DOXY_QC'][:] = profile
#     nc.close()
