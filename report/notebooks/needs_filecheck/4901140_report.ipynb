# %% [markdown]
# # DMQC Report: WMO 4901140
#
# ## Current status and metadata:
#
# - APEX float in the North Atlantic, starting off the scotian shelf and ending up in less than 1000m of water near Florida
# - Completed 151 cycles from May 2010 to June 2014
# - Already in delayed mode, but appears in DOXY audit
# - Gain value using raw data is 1.117
# - Appears to be 2 gains applied to current adjusted data, 1.126 and 0.902, believe the 0.902 gains are what is flagged in the DOXY audit.
# - SCIENTIFIC_CALIB_COMMENT for some say G obtained from DOXY audit, but for 0.902 gains say calculated using in-air data

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt

from netCDF4 import Dataset

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4901140 # insert WMO number here
fig_path = Path('../../../figures/') / f'{wmo}' # where to save figures
fig_path.mkdir(exist_ok=True)
bgc.io.get_argo(wmo, local_path=bgc.io.Path.ARGO_PATH) # download the data to ensure you have up to date files
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA') # calculate gain, can change to ref='NCEP' if in-air data is available
print(np.nanmean(gains))
# Out:
# \Users\GordonC\Documents\data\Argo\dac\meds\4901140\4901140_Rtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901140\4901140_Sprof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901140\4901140_meta.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901140\4901140_prof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901140\4901140_tech.nc
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.117268195077534

# %%
print(np.nanmean(gains))
print((flt.df.DOXY_ADJUSTED/flt.df.DOXY).unique())
# Out:
# 1.117268195077534
# [1.126      1.1260002         nan 1.1259999  0.90200007 0.9020001
#  0.90199995 0.9020002  0.902      0.9019999  0.9019998  0.90199983
#  0.9019997  0.90200025 0.9020003 ]

# %% [markdown]
# ## DOXY Audit Status
#
# - If the float has any profiles present in the DOXY audit, which are they are why?
# - Likely will usually be left empty/deleted

# %%
audit_file = list(Path('../../../audit/').glob('DOXY_WOA*'))[-1]
df = pd.read_csv(audit_file, sep='\t', header=25)
df = df.loc[df.WMO == wmo]
df['date'] = [datestr2num(t) for t in df['profile date']]
print(df)
# Out:
#      DAC             PI SPROF DATE_UPDATE DATA MODE      WMO  cycle  \
# 11  meds  Blair Greenan    06/28/22 20:03         D  4901140     12
# 12  meds  Blair Greenan    06/28/22 20:03         D  4901140     13
# 13  meds  Blair Greenan    06/28/22 20:03         D  4901140     16
# 14  meds  Blair Greenan    06/28/22 20:03         D  4901140     20
# 15  meds  Blair Greenan    06/28/22 20:03         D  4901140     27
# 16  meds  Blair Greenan    06/28/22 20:03         D  4901140     30
# 17  meds  Blair Greenan    06/28/22 20:03         D  4901140     33
# 18  meds  Blair Greenan    06/28/22 20:03         D  4901140     51
# 19  meds  Blair Greenan    06/28/22 20:03         D  4901140     53
# 20  meds  Blair Greenan    06/28/22 20:03         D  4901140     64
# 21  meds  Blair Greenan    06/28/22 20:03         D  4901140     68
# 27        89.96           81.15       1.12       1.24      0.97       9.6
# 28        90.59           81.71       1.13       1.26      1.26      10.2
# 29        89.53           80.76       1.13       1.26      1.25      10.2
#
#             date
# 11  14843.186111
# 12  14853.252083
# 13  14883.168750
# 14  14923.171528
# 15  14993.197917
# 16  15023.102083
# 17  15053.204861
# 18  15233.187500
# 19  15253.168056
# 20  15363.177083
# 21  15403.106944
# 22  15433.086806
# 23  15563.104861
# 24  15723.104167
# 25  15783.153472
# 26  15923.095139
# 27  16023.103472
# 28  16123.113889
# 29  16133.104167
#
# [19 rows x 22 columns]

# %% [markdown]
# ## Visual QC
#
# - Visualize the float and reference surface saturations, as well as the profiles.
# - Observe if DOXY data is set to '3' as it should be or if it is '1' or '2'.
# - Try to note cycles or other identifying features of potentially problematic profiles.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(df['date'], df['flt O2 %sat'], '*')
g.axes[1].plot(df['date'], df['WOA G_raw'], '*', zorder=3)
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars, if applicable) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes:
#
# - The spike in late 2010/early 2011 is suspicious to me, should investigate
# - The dramatic change in early 2013 is not as concerning to me. Looking at the float trajectory, it very well could have moved into a different water mass with slightly different chemical properties. Using WOA may be too coarse to capture this, so although it is not reflected in the reference data, I hesitate to mark it as bad. Will still visualize those profiles to investigate further.

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'O2Sat', 'TEMP', 'PSAL'])
g = flt.plot('qcprofiles', varlist=['DOXY', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((200,0))
g = flt.plot('profiles', varlist=['DOXY', 'O2Sat', 'TEMP', 'PSAL'])

# %% [markdown]
# Figures 2, 3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Figure 4: Profiles coloured by time, darker=more recent, lighter=older.
#
# Notes: The spike mentioned above does not appear to lie greatly outside the profile, so I remain hesitant to mark it as bad. Plan is to leave it in as good. Could downgrade to 2 if I really wanted?

# %% [markdown]
# ## Flag bad data, recalculate gain
#
# - Using the plots above (and likely some more specific plots, made on a case-by-case basis), flag bad DOXY data as 4.
# - After flagging bad data, re-clean the data and re-calculate the gains.

# %%
bad_oxygen = [] # index defining where the oxygen should be flagged as bad
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
print(np.nanmean(new_gains))

g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(df['date'], df['flt O2 %sat'], '*')
g.axes[1].plot(df['date'], df['WOA G_raw'], '*', zorder=3)
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
# Out:
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.117268195077534

# %% [markdown]
# Figure x: Repeated gain plot with bad data removed.
#
# ## Update Fields and Export
#
# - DOXY should be 3 by default, but many old floats have 1 or 0. Though it will be redundant in some cases, make sure DOXY_QC is not good.
# - Apply the gain to calculate DOXY_ADJUSTED.
# - Fill in DOXY_ADJUSTED_ERROR with an appropriate fixed value.
# - Fill in DOXY_ADJUSTED_QC.
# - Make sure DOXY_ADJUSTED and DOXY_ADJUSTED_ERROR are `FillValue` wherever DOXY_ADJUSTED_QC is bad.
# - Export the D-mode files. During export, HISTORY parameters will be filled as well as SCIENTIFIC_CALIB parameters using some default structures and user info set by calling `bgc.configure.configure()`.

# %%
# make sure DOXY_QC is 3 instead of 0,1,2
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC.isin([0, 1, 2]))
# apply gain and calculate error
flt.update_field('DOXY_ADJUSTED', flt.gain*flt.DOXY)
flt.update_field('DOXY_ADJUSTED_ERROR', bgc.calc_fixed_doxy_adjusted_error(flt.PSAL, flt.TEMP, flt.PRES))
# fill in DOXY_ADJUSTED_QC appropriately
flt.update_field('DOXY_ADJUSTED_QC', flt.DOXY_QC)
flt.update_field('DOXY_ADJUSTED_QC', 1, where=flt.DOXY_ADJUSTED_QC.isin([0, 3]))
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.TEMP_ADJUSTED_QC == 4)
flt.update_field('DOXY_ADJUSTED_QC', 3, where=flt.PSAL_ADJUSTED_QC == 4)
# make sure the data is FillValues where adjusted values are still bad
flt.set_fillvalue('DOXY_ADJUSTED', where=flt.DOXY_ADJUSTED_QC == 4)
flt.set_fillvalue('DOXY_ADJUSTED_ERROR', where=flt.DOXY_ADJUSTED_QC == 4)

# %%
# export the files
flt.export_files(data_mode='D', glob='BD*')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_045.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_071.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_080.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_082.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_083.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_084.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_085.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_086.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_087.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_088.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_089.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_090.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_091.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_092.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_093.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_094.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_095.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_096.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_097.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_098.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_099.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_100.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_101.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_102.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_103.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_104.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_105.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_106.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_107.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_108.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_109.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_110.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_111.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_112.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_113.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_114.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_115.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_116.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_117.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_118.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_119.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_120.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_121.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_122.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_123.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_124.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_125.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_126.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_127.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_128.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_129.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_130.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_131.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_132.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_133.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_134.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_135.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_136.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_137.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_138.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_139.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_140.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_141.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_142.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_143.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_145.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_146.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_147.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_149.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_150.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901140/profiles/BD4901140_151.nc...done
