# %% [markdown]
# # DMQC Report: WMO 4901784
#
# ## Current status and metadata:
#
# - DOVA float, inactive as of November 2021
# - Completed 234 cycles in mid-North Pacific
# - In 'A' mode
# - Adjusted data is erroneously high, large gain of 1.61 applied to raw DOXY
# - Calculate mean gain of 1.0496

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4901784
flt = bgc.sprof(4901784)
flt.clean()
gains = flt.calc_gains(ref='WOA')
print(np.nanmean(gains))

# flt.plot('map') # not built yet
# Out:
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0496571477667611

# %% [markdown]
# ## DOXY Audit Status
#
# - Many points flagged as problematic, likely due to the erroneously high adjusted value
# - Mean raw DOXY gain of 1.0472

# %%
audit_file = list(Path('../../audit/').glob('DOXY_WOA*'))[-1]
df = pd.read_csv(audit_file, sep='\t', header=25)
df = df.loc[df.WMO == wmo]
df['date'] = [datestr2num(t) for t in df['profile date']]
print(f"{df['WOA G_raw'].mean():.4f}")
# Out:
# 1.0472

# %% [markdown]
# ## Visual QC
#
# Check the profiles and any anomolous looking saturation values.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(df['date'], df['flt O2 %sat'], '*')
g.axes[1].plot(df['date'], df['WOA G_raw'], '*')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars) and raw float percent saturation (orange circles, background). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars, background).
#
# Notes: seemingly problematic profiles in early 2017 and mid-2020. DOXY audit flags a lot of points that are probably good, but that is due to the erroneously high adjusted DOXY (bad gain of 1.61 applied). Possibly coincidental, but that outlier gain is about 1.61 - perhaps a point was flagged in a previous DOXY audit, and accidentally applied to the float rather than being flagged as 4. SCIENTIFIC_CALIB_COMMENT states "G obtained from DOXY audit on 2020-02-24".

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY'])
g = flt.plot('qcprofiles', varlist=['DOXY'])
g.axes[0].set_ylim((200,0))
# Out:
# (200.0, 0.0)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: Can pretty clearly see the two deliquent profiles shown in figure 1. Will isolate those profiles and consider whether to make the whole profile as bad or just the top sections of them.

# %%
problem_cycles = flt.df.CYCLE.loc[(flt.df.DOXY < 200) & (flt.df.PRES < 50)].unique()
print(problem_cycles)
# Out:
# [ 61. 190.]

# %%
fig, ax = plt.subplots()
ix = flt.df.CYCLE.isin(problem_cycles)
ax.plot(flt.df.O2Sat, flt.df.PRES, '.')
ax.plot(flt.df.O2Sat.loc[ix], flt.df.PRES.loc[ix], '.')
flt.clean()
ax.plot(flt.df.O2Sat.loc[ix], flt.df.PRES.loc[ix], '.')
ax.set_ylim((2000,0))
ax.axhline(300)

flt.reset()
fig, ax = plt.subplots()
ix = flt.df.CYCLE.isin(problem_cycles)
ax.plot(flt.df.O2Sat, flt.df.PRES, '.')
ax.plot(flt.df.O2Sat.loc[ix], flt.df.PRES.loc[ix], '.')
flt.clean()
ax.plot(flt.df.O2Sat.loc[ix], flt.df.PRES.loc[ix], '.')
ax.set_ylim((200,0))
ax.set_xlim((0, 120))
# Out:
# (0.0, 120.0)

# %% [markdown]
# Figures 4, 5: Better highlights of the problem profiles. There are some DOXY_QC=4 already (orange points).
#
# Notes: I think either more or all of these two profiles should be flagged bad. Below 300 dbar looks ok to me so for now I will keep those points.
#
# ## Flag bad data, recalculate gain
#
# - new mean gain of 1.0466

# %%
bad_oxygen = flt.df.CYCLE.isin(problem_cycles) & (flt.df.PRES < 300)
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
print(np.nanmean(new_gains))
# Out:
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.046568580195037

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(df['date'], df['flt O2 %sat'], '*')
g.axes[1].plot(df['date'], df['WOA G_raw'], '*')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)

# %%
# get the mean gain
flt.update_field('DOXY_ADJUSTED', flt.gain*flt.DOXY)
flt.update_field('DOXY_ADJUSTED_ERROR', bgc.calc_fixed_doxy_adjusted_error(flt.PSAL, flt.TEMP, flt.PRES))
flt.update_field('DOXY_ADJUSTED_QC', flt.DOXY_QC)
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC == 1)
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC == 0)
flt.update_field('DOXY_ADJUSTED_QC', 2, where=flt.DOXY_ADJUSTED_QC == 3)
flt.update_field('DOXY_ADJUSTED_QC', 2, where=flt.DOXY_ADJUSTED_QC == 0)

# %%
flt.export_files(data_mode='D')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_000.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_045.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_080.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_082.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_083.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_084.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_085.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_086.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_087.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_088.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_089.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_090.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_091.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_092.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_093.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_094.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_095.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_096.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_097.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_098.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_099.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_100.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_101.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_102.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_103.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_104.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_105.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_106.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_107.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_108.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_109.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_110.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_111.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_112.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_113.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_114.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_115.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_116.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_117.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_118.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_119.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_120.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_121.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_122.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_123.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_124.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_125.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_126.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_127.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_128.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_129.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_130.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_131.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_132.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_133.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_134.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_135.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_136.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_137.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_138.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_139.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_140.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_141.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_142.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_143.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_144.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_145.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_146.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_147.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_148.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_149.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_150.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_151.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_152.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_153.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_154.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_155.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_157.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_158.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_159.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_160.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_161.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_162.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_163.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_164.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_165.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_166.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_167.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_168.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_169.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_170.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_171.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_172.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_173.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_174.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_175.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901784/profiles/BD4901784_176.nc...done
