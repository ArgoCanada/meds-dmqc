# %% [markdown]
# # DMQC Report: WMO 4902390
#
# ## Current status and metadata:
#
# - MetOcean NOVA float deployed off Scotia Shelf
# - Deployed in September 2017
# - Only completed 15 cycles
# - No in-air data
# - Core files in R mode

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt

from netCDF4 import Dataset

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4902390 # insert WMO number here
fig_path = Path('../../../figures/') / f'{wmo}' # where to save figures
fig_path.mkdir(exist_ok=True)
bgc.io.get_argo(wmo, local_path=bgc.io.Path.ARGO_PATH) # download the data to ensure you have up to date files
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA') # calculate gain, can change to ref='NCEP' if in-air data is available
print(np.nanmean(gains))

# check what/if anything is done already
nc = Dataset(flt.__Sprof__)
print(bgc.io.read_ncstr(nc['SCIENTIFIC_CALIB_COMMENT'][:][1,-1,3,:]))
print(nc['DOXY_ADJUSTED'][:][-1,:]/nc['DOXY'][:][-1,:])
nc.close()
# Out:
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\4902390_BRtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\4902390_Rtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\4902390_Sprof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\4902390_meta.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\4902390_prof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\4902390_tech.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_000.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_001.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_002.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_003.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_004.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_005.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_006.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_007.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_008.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_009.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_010.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_011.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_012.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_013.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\R4902390_014.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_000.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_001.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_002.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_003.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_004.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_005.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_006.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_007.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_008.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_009.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_010.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_011.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_012.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_013.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4902390\profiles\SR4902390_014.nc
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0526509414394287
#
# [-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- --]

# %% [markdown]
# ## DOXY Audit Status
#
# - If the float has any profiles present in the DOXY audit, which are they are why?
# - Likely will usually be left empty/deleted

# %%
audit_file = list(Path('../../../audit/').glob('DOXY_WOA*'))[-1]
df = pd.read_csv(audit_file, sep='\t', header=25)
df = df.loc[df.WMO == wmo]
df['date'] = [datestr2num(t) for t in df['profile date']]
print(df['WOA G_raw'].mean())
# Out:
# nan

# %% [markdown]
# ## Visual QC
#
# - Visualize the float and reference surface saturations, as well as the profiles.
# - Observe if DOXY data is set to '3' as it should be or if it is '1' or '2'.
# - Try to note cycles or other identifying features of potentially problematic profiles.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_initial.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars, if applicable) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes: [notes on what this figure tells you here]

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.fig.savefig(fig_path / 'qcprofiles.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((400, 0))
g.axes[0].set_xlim((0, 260))
g.axes[2].set_xlim((0, 110))
g.fig.savefig(fig_path / 'qcprofiles_shallow.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: [notes on what this figure tells you here]

# %% [markdown]
# ## Flag bad data, recalculate gain
#
# - Using the plots above (and likely some more specific plots, made on a case-by-case basis), flag bad DOXY data as 4.
# - After flagging bad data, re-clean the data and re-calculate the gains.

# %%
flt.reset()
bad_oxygen = [] # index defining where the oxygen should be flagged as bad
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
G = np.nanmean(new_gains)
print(G)

flt.update_field('DOXY_ADJUSTED', G*flt.DOXY)
flt.update_field('DOXY_ADJUSTED_QC', flt.DOXY_QC)
flt.update_field('DOXY_ADJUSTED_QC', 1, where=flt.DOXY_QC == 3)
flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
# Out:
# Updating DOXY_QC on 0 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0526509414394287
# Updating DOXY_ADJUSTED on all levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Updating DOXY_ADJUSTED_QC on all levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Updating DOXY_ADJUSTED_QC on 0 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Updating DOXY_ADJUSTED_QC on 0 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC

# %% [markdown]
# Figure x: Repeated gain plot with bad data removed.
#
# ## Update Fields and Export
#
# - DOXY should be 3 by default, but many old floats have 1 or 0. Though it will be redundant in some cases, make sure DOXY_QC is not good.
# - Apply the gain to calculate DOXY_ADJUSTED.
# - Fill in DOXY_ADJUSTED_ERROR with an appropriate fixed value.
# - Fill in DOXY_ADJUSTED_QC.
# - Make sure DOXY_ADJUSTED and DOXY_ADJUSTED_ERROR are `FillValue` wherever DOXY_ADJUSTED_QC is bad.
# - Export the D-mode files. During export, HISTORY parameters will be filled as well as SCIENTIFIC_CALIB parameters using some default structures and user info set by calling `bgc.configure.configure()`.

# %%
# make sure DOXY_QC is 3 instead of 0,1,2
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC.isin([0, 1, 2]))
# fill in DOXY_ADJUSTED_QC appropriately
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.TEMP_ADJUSTED_QC == 4)
flt.update_field('DOXY_ADJUSTED_QC', 3, where=flt.PSAL_ADJUSTED_QC == 4)
# make sure the data is FillValues where adjusted values are still bad
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.DOXY_ADJUSTED.isna())
flt.set_fillvalue('DOXY_ADJUSTED', where=flt.DOXY_ADJUSTED_QC == 4)
flt.set_fillvalue('DOXY_ADJUSTED_ERROR', where=flt.DOXY_ADJUSTED_QC == 4)

flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[1].set_xlim(g.axes[0].get_xlim())
g.fig.savefig(fig_path / 'qcprofiles_postqc.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((2000, 1250))
g.fig.savefig(fig_path / 'qcprofiles_deep_postqc.png', bbox_inches='tight', dpi=250)

flt.clean()
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_final.png', bbox_inches='tight', dpi=250)
# Out:
# Updating DOXY_QC on 0 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Updating DOXY_ADJUSTED_QC on 102 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Updating DOXY_ADJUSTED_QC on 102 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Updating DOXY_ADJUSTED_QC on 614 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Updating DOXY_ADJUSTED on 614 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# Updating DOXY_ADJUSTED_ERROR on 614 levels
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC
# hello POSITION_QC
# hello PRES_QC
# hello PRES_ADJUSTED_QC
# hello TEMP_QC
# hello TEMP_ADJUSTED_QC
# hello PSAL_QC
# hello PSAL_ADJUSTED_QC
# hello DOXY_QC
# hello DOXY_ADJUSTED_QC
# hello O2Sat_QC

# %%
# export the files - for R to D mode
flt.export_files(data_mode='D')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_000.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_001.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_002.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_003.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_004.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_005.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_006.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_007.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_008.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_009.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_010.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_011.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_012.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_013.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4902390/profiles/BD4902390_014.nc...('N_PROF', 'N_CALIB', 'N_PARAM', 'STRING256') 0 0 2
# done

# %%
# from pathlib import Path
# import pandas as pd
# from netCDF4 import Dataset
# import copy

# wmo = 4900874
# loc = Path(f'/Users/GordonC/Documents/data/Argo/dac/meds/D/{wmo}/profiles/')
# files = pd.read_csv(Path(f'../../../checker/summary/{wmo}/files.txt'))
# varname = 'DOXY'
# for fn in files.files:
#     print(fn)
#     nc = Dataset(loc / fn, 'r+')
#     print(nc['DOXY'][:])
#     flags = copy.deepcopy(nc[varname+'_QC'][:])
#     flags[nc[varname][:].mask] = b'9'
#     nc[varname+'_QC'][:] = flags
#     if varname == 'DOXY':
#         flags = copy.deepcopy(nc[varname+'_ADJUSTED_QC'][:])
#         flags[nc[varname][:].mask] = b'9'
#         nc[varname+'_ADJUSTED_QC'][:] = flags
#     profile = copy.deepcopy(nc['PROFILE_DOXY_QC'][:])
#     profile[0] = b'A'
#     nc['PROFILE_DOXY_QC'][:] = profile
#     nc.close()
