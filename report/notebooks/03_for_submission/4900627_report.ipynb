# %% [markdown]
# # DMQC Report: WMO 4900627
#
# ## Current status and metadata:
#
# - APEX float deployed off Scotian Shelf, stayed generally in that area for its entire lifetime
# - Deployed in October 2005
# - Completed 174 cycles over 5 years
# - Already adjusted by Henry Bittig, mean gain 1.00347
# - WOA gain 1.00378

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt

from netCDF4 import Dataset

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4900627 # insert WMO number here
fig_path = Path('../../../figures/') / f'{wmo}' # where to save figures
fig_path.mkdir(exist_ok=True)
bgc.io.get_argo(wmo, local_path=bgc.io.Path.ARGO_PATH) # download the data to ensure you have up to date files
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA') # calculate gain, can change to ref='NCEP' if in-air data is available
print(np.nanmean(gains))

# check what/if anything is done already
nc = Dataset(flt.__Sprof__.absolute())
print(bgc.io.read_ncstr(nc['SCIENTIFIC_CALIB_COMMENT'][:][2,-1,3,:]))
print(nc['DOXY_ADJUSTED'][:][-1,:]/nc['DOXY'][:][-1,:])
print(np.nanmean(nc['DOXY_ADJUSTED'][:][-1,:]/nc['DOXY'][:][-1,:]))
nc.close()
# Out:
# \Users\GordonC\Documents\data\Argo\dac\meds\4900627\4900627_BRtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900627\4900627_Rtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900627\4900627_Sprof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900627\4900627_meta.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900627\4900627_prof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900627\4900627_tech.nc
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0037778027565043
# by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY; Using in-air obs; No time response correction done; error gives 1 sigma
# [0.9753938317298889 0.9753959774971008 0.9749900698661804
#  0.9750750660896301 0.9762864708900452 0.9797102808952332
#  0.9805837273597717 0.9813637733459473 0.9830108880996704
#  0.9844921827316284 0.9850425720214844 0.9857885837554932
#  0.9867088794708252 0.9875972270965576 0.98846435546875 0.9889658689498901
#  0.9900306463241577 0.9908382892608643 0.9913356304168701
#  0.9915565848350525 0.9921537637710571 0.9924875497817993
#  0.9929698705673218 0.9934247136116028 0.9939411282539368
#  0.9942132234573364 0.99455326795578 0.9946531057357788 0.9948422908782959
#  0.9952205419540405 0.9955946207046509 0.9956647753715515
#  0.9960600733757019 0.9963384866714478 0.9966232180595398
#  0.9970632195472717 0.9973841309547424 0.997724175453186
#  0.9984977841377258 1.0011628866195679 1.0048757791519165
#  1.0080338716506958 1.0107202529907227 1.013136625289917
#  1.0153555870056152 1.0182245969772339 1.0204030275344849
#  1.0218439102172852 1.0226303339004517 1.0234570503234863
#  1.0239331722259521 1.024251937866211 1.025012731552124 1.0253316164016724
#  1.0256460905075073 1.025767207145691 1.025935173034668 1.02595853805542
#  1.0260223150253296 1.0262773036956787 -- 1.0265324115753174
#  1.0266960859298706 1.0267724990844727 1.0268977880477905
#  1.0270105600357056 1.0271741151809692 1.0272549390792847
#  1.0273271799087524 1.027414321899414 --]
# 1.0034652

# %% [markdown]
# ## Visual QC
#
# - Visualize the float and reference surface saturations, as well as the profiles.
# - Observe if DOXY data is set to '3' as it should be or if it is '1' or '2'.
# - Try to note cycles or other identifying features of potentially problematic profiles.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_initial.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars, if applicable) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes: [notes on what this figure tells you here]

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.fig.savefig(fig_path / 'qcprofiles.png', bbox_inches='tight', dpi=250)
# g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
# g.axes[0].set_ylim((400, 0))
# g.axes[0].set_xlim((0, 260))
# g.axes[2].set_xlim((0, 110))
# g.fig.savefig(fig_path / 'qcprofiles_shallow.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: [notes on what this figure tells you here]

# %% [markdown]
# ## Flag bad data, recalculate gain
#
# - Using the plots above (and likely some more specific plots, made on a case-by-case basis), flag bad DOXY data as 4.
# - After flagging bad data, re-clean the data and re-calculate the gains.

# %%
flt.reset()
bad_oxygen = [] # index defining where the oxygen should be flagged as bad
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
G = np.nanmean(new_gains)
print(G)

flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
# Out:
# Updating DOXY_QC on 0 levels
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0037778027565043
# Updating DOXY_ADJUSTED_QC on 0 levels

# %% [markdown]
# Figure x: Repeated gain plot with bad data removed.
#
# ## Update Fields and Export
#
# - DOXY should be 3 by default, but many old floats have 1 or 0. Though it will be redundant in some cases, make sure DOXY_QC is not good.
# - Apply the gain to calculate DOXY_ADJUSTED.
# - Fill in DOXY_ADJUSTED_ERROR with an appropriate fixed value.
# - Fill in DOXY_ADJUSTED_QC.
# - Make sure DOXY_ADJUSTED and DOXY_ADJUSTED_ERROR are `FillValue` wherever DOXY_ADJUSTED_QC is bad.
# - Export the D-mode files. During export, HISTORY parameters will be filled as well as SCIENTIFIC_CALIB parameters using some default structures and user info set by calling `bgc.configure.configure()`.

# %%
# make sure DOXY_QC is 3 instead of 0,1,2
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC.isin([0, 1, 2]))
# fill in DOXY_ADJUSTED_QC appropriately
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.TEMP_ADJUSTED_QC == 4)
flt.update_field('DOXY_ADJUSTED_QC', 3, where=flt.PSAL_ADJUSTED_QC == 4)
# make sure the data is FillValues where adjusted values are still bad
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.DOXY_ADJUSTED.isna())
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.DOXY_ADJUSTED == flt.__fillvalue__['DOXY_ADJUSTED'])
flt.set_fillvalue('DOXY_ADJUSTED', where=flt.DOXY_ADJUSTED_QC == 4)
flt.set_fillvalue('DOXY_ADJUSTED_ERROR', where=flt.DOXY_ADJUSTED_QC == 4)

flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[1].set_xlim(g.axes[0].get_xlim())
g.fig.savefig(fig_path / 'qcprofiles_postqc.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.fig.savefig(fig_path / 'qcprofiles_deep_postqc.png', bbox_inches='tight', dpi=250)

flt.clean()
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_final.png', bbox_inches='tight', dpi=250)
# Out:
# Updating DOXY_QC on 11750 levels
# Updating DOXY_ADJUSTED_QC on 30 levels
# Updating DOXY_ADJUSTED_QC on 141 levels
# Updating DOXY_ADJUSTED_QC on 375 levels
# Updating DOXY_ADJUSTED_QC on 44 levels
# Updating DOXY_ADJUSTED on 419 levels
# Updating DOXY_ADJUSTED_ERROR on 419 levels

# %%
# export the files - for A to D mode
comment = 'by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma'
comment += f"; Visual QC by Christopher Gordon (DFO, ORCID {bgc.config['orcid']})"
comment = comment.replace('No time response correction done;', '')
flt.export_files(data_mode='D', comment=comment, coeff='previous', equation='previous')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_071.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_080.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_082.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_083.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_084.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_085.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_086.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_087.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_088.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_089.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_090.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_091.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_092.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_093.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_094.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_095.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_096.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_097.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_098.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_100.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_101.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_102.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_103.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_104.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_105.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_106.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_107.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_108.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_109.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_110.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_111.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_112.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_113.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_114.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_115.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_116.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_117.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_118.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_119.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_120.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_121.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_122.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_123.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_124.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_125.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_126.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_127.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_128.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_129.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_130.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_131.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_132.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_133.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_134.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_135.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_136.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_137.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_138.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_139.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_140.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_141.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_142.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_143.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_144.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_145.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_146.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_147.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_148.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_149.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_150.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_151.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_152.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_153.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_154.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_155.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_156.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_157.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_158.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_159.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_160.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_161.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_162.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_163.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_164.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_165.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_166.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_167.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_168.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_169.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_170.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_171.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_172.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_173.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900627/profiles/BD4900627_174.nc...done
