# %% [markdown]
# # DMQC Report: WMO 4901135
#
# ## Current status and metadata:
#
# - APEX float in Pacific Ocean
# - Deployed in August 2010, inactive since September 2012
# - Completed 83 cycles over 2.5 years
# - Core files in D-mode, Oxygen in A-mode adjusted using DOXY audit values from Josh Plant

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt
import seaborn as sns

from netCDF4 import Dataset

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4901135 # insert WMO number here
fig_path = Path('../../../figures/') / f'{wmo}' # where to save figures
fig_path.mkdir(exist_ok=True)
bgc.io.get_argo(wmo, local_path=bgc.io.Path.ARGO_PATH) # download the data to ensure you have up to date files
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA') # calculate gain, can change to ref='NCEP' if in-air data is available
print(np.nanmean(gains))

# check what/if anything is done already
nc = Dataset(flt.__Sprof__.absolute())
print(bgc.io.read_ncstr(nc['SCIENTIFIC_CALIB_COMMENT'][:][50,-1,3,:]))
print(nc['DOXY_ADJUSTED'][:][-1,:]/nc['DOXY'][:][-1,:])
nc.close()
# Out:
# \Users\GordonC\Documents\data\Argo\dac\meds\4901135\4901135_Rtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901135\4901135_Sprof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901135\4901135_meta.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901135\4901135_prof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4901135\4901135_tech.nc
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0898500352926506
# by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 21 slope on PPOX_DOXY; Using in-air obs; No time response correction done; error gives 1 sigma
# [1.0804237127304077 1.0804235935211182 1.0804237127304077
#  1.0804235935211182 1.0804235935211182 1.0804235935211182
#  1.0804235935211182 1.0804235935211182 1.0804235935211182
#  1.0804235935211182 1.0804235935211182 1.0804235935211182
#  1.0804235935211182 1.0804237127304077 1.0804235935211182
#  1.0804235935211182 1.0804235935211182 1.0804235935211182
#  1.0804235935211182 1.0804237127304077 1.0804237127304077
#  1.0804235935211182 1.0804237127304077 1.0804237127304077
#  1.0804235935211182 1.0804235935211182 1.0804237127304077
#  1.0804235935211182 1.0804235935211182 1.0804237127304077
#  1.0804237127304077 1.0804235935211182 1.0804237127304077
#  1.0804235935211182 1.0804235935211182 1.0804235935211182
#  1.0804235935211182 1.0804235935211182 1.0804237127304077
#  1.080423355102539 1.0804234743118286 1.0804239511489868 1.080423355102539
#  1.080423355102539 1.0804239511489868 1.0804239511489868 1.080423355102539
#  1.0804238319396973 1.0804232358932495 1.080423355102539
#  1.0804235935211182 -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- --]

# %% [markdown]
# ## DOXY Audit Status
#
# - If the float has any profiles present in the DOXY audit, which are they are why?
# - Likely will usually be left empty/deleted

# %%
audit_file = list(Path('../../../audit/').glob('DOXY_WOA*'))[-1]
df = pd.read_csv(audit_file, sep='\t', header=25)
df = df.loc[df.WMO == wmo]
df['date'] = [datestr2num(t) for t in df['profile date']]
print(df['WOA G_raw'].mean())
# Out:
# nan

# %% [markdown]
# ## Visual QC
#
# - Visualize the float and reference surface saturations, as well as the profiles.
# - Observe if DOXY data is set to '3' as it should be or if it is '1' or '2'.
# - Try to note cycles or other identifying features of potentially problematic profiles.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_initial.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars, if applicable) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes: [notes on what this figure tells you here]

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.fig.savefig(fig_path / 'qcprofiles.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((205, -5))
g.fig.savefig(fig_path / 'qcprofiles_shallow.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: [notes on what this figure tells you here]

# %% [markdown]
# ## Flag bad data, recalculate gain
#
# - Using the plots above (and likely some more specific plots, made on a case-by-case basis), flag bad DOXY data as 4.
# - After flagging bad data, re-clean the data and re-calculate the gains.

# %%
flt.reset(hard=True)
bad_oxygen = (flt.df.PRES < 1180) & (flt.df.PRES > 740)
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
G = np.nanmean(new_gains)
print(G)

flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
flt.update_field('DOXY_ADJUSTED_ERROR', bgc.calc_fixed_doxy_adjusted_error(flt.PSAL, flt.TEMP, flt.PRES))
# Out:
# Warning: hard resetting back to original file values. Any changes from update_field() or set_fillvalue() will be lost.
# Updating DOXY_QC on 624 levels
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0898500352926506
# Updating DOXY_ADJUSTED_QC on 624 levels
# Updating DOXY_ADJUSTED_ERROR on all levels

# %% [markdown]
# Figure x: Repeated gain plot with bad data removed.
#
# ## Update Fields and Export
#
# - DOXY should be 3 by default, but many old floats have 1 or 0. Though it will be redundant in some cases, make sure DOXY_QC is not good.
# - Apply the gain to calculate DOXY_ADJUSTED.
# - Fill in DOXY_ADJUSTED_ERROR with an appropriate fixed value.
# - Fill in DOXY_ADJUSTED_QC.
# - Make sure DOXY_ADJUSTED and DOXY_ADJUSTED_ERROR are `FillValue` wherever DOXY_ADJUSTED_QC is bad.
# - Export the D-mode files. During export, HISTORY parameters will be filled as well as SCIENTIFIC_CALIB parameters using some default structures and user info set by calling `bgc.configure.configure()`.

# %%
# make sure DOXY_QC is 3 instead of 0,1,2
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC.isin([0, 1, 2]))
# fill in DOXY_ADJUSTED_QC appropriately
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.TEMP_ADJUSTED_QC == 4)
flt.update_field('DOXY_ADJUSTED_QC', 3, where=flt.PSAL_ADJUSTED_QC == 4)
# make sure the data is FillValues where adjusted values are still bad
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.DOXY_ADJUSTED.isna())
flt.set_fillvalue('DOXY_ADJUSTED', where=flt.DOXY_ADJUSTED_QC == 4)
flt.set_fillvalue('DOXY_ADJUSTED_ERROR', where=flt.DOXY_ADJUSTED_QC == 4)

flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[1].set_xlim(g.axes[0].get_xlim())
g.fig.savefig(fig_path / 'qcprofiles_postqc.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((205, -5))
g.fig.savefig(fig_path / 'qcprofiles_shallow_postqc.png', bbox_inches='tight', dpi=250)

flt.clean()
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_final.png', bbox_inches='tight', dpi=250)
# Out:
# Updating DOXY_QC on 0 levels
# Updating DOXY_ADJUSTED_QC on 0 levels
# Updating DOXY_ADJUSTED_QC on 0 levels
# Updating DOXY_ADJUSTED_QC on 1481 levels
# Updating DOXY_ADJUSTED on 1481 levels
# Updating DOXY_ADJUSTED_ERROR on 1481 levels

# %%
g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED', 'O2Sat', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((1100, 900))
g.axes[0].set_xlim((-1, 21))
g.axes[1].set_xlim((-1, 21))
g.fig.savefig(fig_path / 'qcprofiles_1000m_postqc.png', bbox_inches='tight', dpi=250)

print(flt.df.loc[(flt.df.PRES > 900) & (flt.df.PRES < 1100), 'DOXY'])

fig, ax = plt.subplots()
sns.scatterplot(data=flt.df, x='DOXY', y='PRES', hue='CYCLE', ax=ax, legend=False)
ax.set_ylim((2050, -50))
fig.savefig(fig_path / 'profiles_cycle_scatter.png', bbox_inches='tight', dpi=250)

fig, ax = plt.subplots()
sns.scatterplot(data=flt.df, x='DOXY', y='PRES', hue='CYCLE', ax=ax, legend=False)
ax.set_ylim((1350, 600))
ax.set_xlim((12, 17.5))
fig.savefig(fig_path / 'profiles_cycle_scatter_zoom.png', bbox_inches='tight', dpi=250)
# Out:
# 48     NaN
# 49     NaN
# 50     NaN
# 51     NaN
# 52     NaN
#         ..
# 5736   NaN
# 5806   NaN
# 5807   NaN
# 5808   NaN
# 5809   NaN
# Name: DOXY, Length: 272, dtype: float32

# %%
# export the files
comment = 'by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma'
comment += f"; Visual QC by Christopher Gordon (DFO, ORCID {bgc.config['orcid']})"
comment = comment.replace('No time response correction done;', '')
flt.export_files(data_mode='D', comment=comment, coeff='previous', equation='previous')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_045.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_071.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4901135/profiles/BD4901135_083.nc...done

# %%
from pathlib import Path
import pandas as pd
import numpy as np
from netCDF4 import Dataset
import copy

def fill_nearest_neighbour(P, param):
    out = copy.deepcopy(param)
    ix = np.where(np.isnan(param[0,:]))
    for i in ix[0]:
        iy = np.where(P[0,:] - P[0,i] == np.nanmin(P[0,:] - P[0,i]))
        out[0,i] = param[0,iy[0][0]]

    return out

wmo = 4901135
loc = Path(f'/Users/GordonC/Documents/data/Argo/dac/meds/D/{wmo}/profiles/')
files = pd.read_csv(Path(f'../../../checker/summary/{wmo}/files.txt'))
varname = 'DOXY'
for fn in files.files:
    print(fn)
    nc = Dataset((loc / fn).absolute(), 'r+')
    qc = copy.deepcopy(nc['DOXY_QC'][:])
    qc[0][-1] = qc[0][-2]
    print(qc)
    nc['DOXY_QC'][:] = qc
    nc.close()
# Out:
# BD4901135_023.nc
# [[b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3'
#   b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3'
#   b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3'
#   b'3' b'3' b'3' b'4' b'4' b'4' b'4' b'4' b'4' b'4']]
# BD4901135_060.nc
# [[b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3'
#   b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3'
#   b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3'
#   b'3' b'3' b'3' b'4' b'4' b'4' b'4' b'4' b'4' b'4' b'4' b'4' b'3' b'3'
#   b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3' b'3'
#   b'3' b'3']]
