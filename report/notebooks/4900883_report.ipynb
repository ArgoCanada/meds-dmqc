# %% [markdown]
# # DMQC Report: WMO 4900883
#
# ## Current status and metadata:
#
# - APEX float inactive as of September 2011
# - Deployed November 2006
# - Completed 174 cycles in North Atlantic, appears to have been deployed off Southeast Grand Bank on NL AZMP
# - In 'A' mode, gain of 0.9917 applied
# - Calculated mean gain of 1.011

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4900883
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA')
print(np.nanmean(gains))

# flt.plot('map') # not built yet
# Out:
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
# Bounding climatological profile(s) missing data - taking simple average of available data.
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0110185184573732

# %% [markdown]
# ## DOXY Audit Status
#
# - Few points in the middle of the mission where there is some "spikiness" in the float surface saturation
# - Cycles between 91-102 are flagged, but not all

# %%
audit_file = list(Path('../../audit/').glob('DOXY_WOA*'))[-1]
df = pd.read_csv(audit_file, sep='\t', header=25)
df = df.loc[df.WMO == wmo]
df['date'] = [datestr2num(t) for t in df['profile date']]
print(df['cycle'])
# Out:
# 4     91
# 5     94
# 6     95
# 7     98
# 8    101
# 9    102
# Name: cycle, dtype: int64

# %% [markdown]
# ## Visual QC
#
# Check the profiles and any anomolous looking saturation values.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(df['date'], df['flt O2 %sat'], '*')
g.axes[1].plot(df['date'], df['WOA G_raw'], '*', zorder=3)
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes: Lots of spiking in the profiles flagged by the audit, though not all of those profiles are flagged and some look reasonable. Outside of that mostly looks good.

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY'])
g = flt.plot('qcprofiles', varlist=['DOXY'])
g.axes[0].set_ylim((250,0))
# Out:
# (250.0, 0.0)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: Can't really see the potentially problematic profiles based on the gain plot, though maybe a couple high points in the very surface. The points flagged as 3 shallower than 250 should probably be downgraded to 4.

# %%
bad_profiles = flt.df.loc[flt.df.CYCLE.isin(df['cycle'])]
bad_profiles
# Out:
#       CYCLE           SDN      WMO   LATITUDE  LONGITUDE         PRES    TEMP  \
# 6480   91.0  14390.527778  4900883  41.293999 -48.296997     4.500000  11.024
# 6481   91.0  14390.527778  4900883  41.293999 -48.296997     9.400000  10.744
# 6482   91.0  14390.527778  4900883  41.293999 -48.296997    19.500000   1.221
# 6483   91.0  14390.527778  4900883  41.293999 -48.296997    29.200001   8.267
# 6484   91.0  14390.527778  4900883  41.293999 -48.296997    39.500000   8.947
# ...     ...           ...      ...        ...        ...          ...     ...
# 7267  102.0  14500.354861  4900883  41.504002 -46.506989  1848.900024   3.873
# 7268  102.0  14500.354861  4900883  41.504002 -46.506989  1899.199951   3.840
# 7269  102.0  14500.354861  4900883  41.504002 -46.506989  1949.300049   3.797
# 7270  102.0  14500.354861  4900883  41.504002 -46.506989  1999.099976   3.743
# 7271  102.0  14500.354861  4900883  41.504002 -46.506989  2003.199951   3.742
#
#       TEMP_QC       PSAL  PSAL_QC  ...  PRES_ADJUSTED  CYCLE_GRID  \
# 6480      1.0  33.437000      1.0  ...       4.400000        91.0
# 6481      1.0  33.402000      1.0  ...       9.299999        91.0
# 6482      4.0  32.687000      1.0  ...      19.400000        91.0
# 6483      1.0  33.903999      1.0  ...      29.100000        91.0
# 6484      1.0  34.082001      1.0  ...      39.400002        91.0
# ...       ...        ...      ...  ...            ...         ...
# 7267      1.0  34.919998      1.0  ...    1848.400024       102.0
# 7268      1.0  34.919998      1.0  ...    1898.699951       102.0
# 7269      1.0  34.919998      1.0  ...    1948.800049       102.0
# 7270      1.0  34.915001      1.0  ...    1998.599976       102.0
# 7271      1.0  34.915001      1.0  ...    2002.699951       102.0
#
#           SDN_GRID  DOXY_ADJUSTED_ERROR  DOXY_dPRES  TEMP_ADJUSTED_QC  \
# 6480  14390.527778            10.747310         0.0               1.0
# 6481  14390.527778            10.809686         0.0               1.0
# 6482  14390.527778            13.482664         0.0               4.0
# 6483  14390.527778            11.331094         0.0               1.0
# 6484  14390.527778            11.144938         0.0               1.0
# ...            ...                  ...         ...               ...
# 7267  14500.354861            10.929336         0.0               1.0
# 7268  14500.354861            10.905733         0.0               1.0
# 7269  14500.354861            10.884969         0.0               1.0
# 7270  14500.354861            10.784136         0.0               1.0
# 7271  14500.354861            10.779536         0.0               1.0
#
#       PSAL_ADJUSTED  LONGITUDE_GRID  PSAL_dPRES  PRES_ADJUSTED_QC
# 6480      33.451973      -48.296997         0.0               1.0
# 6481      33.416954      -48.296997         0.0               1.0
# 6482   99999.000000      -48.296997         0.0               1.0
# 6483      33.919151      -48.296997         0.0               1.0
# 6484      34.097240      -48.296997         0.0               1.0
# ...             ...             ...         ...               ...
# 7267      34.935764      -46.506989         0.0               1.0
# 7268      34.935757      -46.506989         0.0               1.0
# 7269      34.935764      -46.506989         0.0               1.0
# 7270      34.930756      -46.506989         0.0               1.0
# 7271      34.930756      -46.506989         0.0               1.0
#
# [424 rows x 35 columns]

# %%
fig, ax = plt.subplots()
flt.rm_fillvalue()
ax.plot(flt.df.O2Sat, flt.df.PRES, '.')
ax.plot(bad_profiles.O2Sat, bad_profiles.PRES, '.')
ax.set_ylim((250,0))

ax.axvline(123.5)
ax.axvline(118)
ax.axvline(75)
ax.axvline(80)
ax.axvline(90)
ax.axvline(45)
ax.axvline(110)

ax.axhline(12)
ax.axhline(27)
ax.axhline(42)

bad = (flt.O2Sat > 123.5)
bad = bad | ((flt.O2Sat < 80) & (flt.PRES < 40))
bad = bad | ((flt.O2Sat < 90) & (flt.PRES < 27))
bad = bad | ((flt.O2Sat < 42) & (flt.PRES > 200) & (flt.PRES < 300))
bad = bad | ((flt.O2Sat > 110) & (flt.PRES > 150) & (flt.PRES < 500))
bad = bad | ((flt.O2Sat < 65) & (flt.PRES > 1300))
bad = bad | ((flt.O2Sat > 95) & (flt.PRES > 1300))
print(sum(bad))
ax.plot(flt.df.O2Sat.loc[bad], flt.df.PRES.loc[bad], 'r^')

fig, ax = plt.subplots()
flt.rm_fillvalue()
ax.plot(flt.df.DOXY, flt.df.PRES, '.')
ax.plot(bad_profiles.DOXY, bad_profiles.PRES, '.')
ax.set_ylim((250,0))

ax.plot(flt.df.DOXY.loc[bad], flt.df.PRES.loc[bad], 'r^')
# Out:
# 30
# 30

# %% [markdown]
# Figure 4: highlight potentially bad profiles, use horizontal/vertical lines to define "bad" indices.

# %%
# get the mean gain
flt.update_field('DOXY_ADJUSTED', flt.gain*flt.DOXY)
flt.update_field('DOXY_ADJUSTED_ERROR', bgc.calc_fixed_doxy_adjusted_error(flt.PSAL, flt.TEMP, flt.PRES))
flt.update_field('DOXY_ADJUSTED_QC', flt.DOXY_QC)
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC == 1)
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC == 0)
flt.update_field('DOXY_ADJUSTED_QC', 1, where=flt.DOXY_ADJUSTED_QC == 3)
flt.update_field('DOXY_ADJUSTED_QC', 1, where=flt.DOXY_ADJUSTED_QC == 0)

flt.update_field('DOXY_QC', 4, where=bad)
flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
print(np.nanmean(new_gains))
# Out:
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0152676493719686

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
# g.axes[0].plot(df['date'], df['flt O2 %sat'], '*')
# g.axes[1].plot(df['date'], df['WOA G_raw'], '*', zorder=3)
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)

g = flt.plot('qcprofiles', varlist=['DOXY', 'DOXY_ADJUSTED'])

# %% [markdown]
# There is still a bit of spikiness in that area but I am hesitant to remove it as it looks well grouped with the rest of the profiles.

# %%
flt.export_files(data_mode='D')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_045.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_071.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_080.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_082.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_083.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_084.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_085.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_086.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_087.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_088.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_089.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_090.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_091.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_092.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_093.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_094.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_095.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_096.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_097.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_098.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_100.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_101.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_102.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_103.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_104.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_105.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_106.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_107.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_108.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_109.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_110.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_111.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_112.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_113.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_114.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_115.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_116.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_117.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_118.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_119.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_120.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_121.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_122.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_123.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_124.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_125.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_126.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_127.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_128.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_129.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_130.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_131.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_132.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_133.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_134.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_135.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_136.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_137.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_138.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_139.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_140.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_141.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_142.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_143.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_144.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_145.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_146.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_147.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_148.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_149.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_150.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_151.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_152.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_153.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_154.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_155.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_156.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_157.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_158.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_159.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_160.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_161.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_162.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_163.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_164.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_165.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_166.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_167.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_168.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_169.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_170.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_171.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_172.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_173.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900883/profiles/BD4900883_174.nc...done
