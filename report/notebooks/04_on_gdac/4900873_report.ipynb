# %% [markdown]
# # DMQC Report: WMO 4900873
#
# ## Current status and metadata:
#
# - APEX float that collected 194 cycles over 5.3 years (2006-2011) in the North Pacific
# - T-dependent gain applied by Henry Bittig - average gain of 1.0363
# - Mean WOA gain of 1.0523
# - Will not change gain - just visually inspect and move to D-mode

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.dates import datestr2num
import matplotlib.pyplot as plt

from netCDF4 import Dataset

from pathlib import Path
import numpy as np
import pandas as pd
import bgcArgoDMQC as bgc

wmo = 4900873 # insert WMO number here
fig_path = Path('../../../figures/') / f'{wmo}' # where to save figures
fig_path.mkdir(exist_ok=True)
bgc.io.get_argo(wmo, local_path=bgc.io.Path.ARGO_PATH) # download the data to ensure you have up to date files
flt = bgc.sprof(wmo)
flt.clean()
gains = flt.calc_gains(ref='WOA') # calculate gain, can change to ref='NCEP' if in-air data is available
print(np.nanmean(gains))

nc = Dataset(flt.__Sprof__)
print(bgc.io.read_ncstr(nc['SCIENTIFIC_CALIB_COMMENT'][:][50,-1,3,:]))
print(nc['DOXY_ADJUSTED'][:][-1,:]/nc['DOXY'][:][-1,:])
print(np.nanmean(nc['DOXY_ADJUSTED'][:]/nc['DOXY'][:]))
nc.close()
# Out:
# \Users\GordonC\Documents\data\Argo\dac\meds\4900873\4900873_Rtraj.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900873\4900873_Sprof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900873\4900873_meta.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900873\4900873_prof.nc
# \Users\GordonC\Documents\data\Argo\dac\meds\4900873\4900873_tech.nc
# Extracting WOA data for Jan
# Extracting WOA data for Feb
# Extracting WOA data for Mar
# Extracting WOA data for Apr
# Extracting WOA data for May
# Extracting WOA data for Jun
# Extracting WOA data for Jul
# Extracting WOA data for Aug
# Extracting WOA data for Sep
# Extracting WOA data for Oct
# Extracting WOA data for Nov
# Extracting WOA data for Dec
#
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0523366140696873
# by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma
# [1.0225334167480469 1.0225324630737305 1.0225343704223633
#  1.0225410461425781 1.0225353240966797 1.022536277770996
#  1.0225372314453125 1.022863507270813 1.0250234603881836
#  1.0265042781829834 1.0271241664886475 1.0276024341583252
#  1.0279324054718018 1.0282758474349976 1.0283992290496826
#  1.0286986827850342 1.0288718938827515 1.0289751291275024
#  1.0292669534683228 1.0293060541152954 1.0294286012649536
#  1.029496431350708 1.0295222997665405 1.029542326927185 1.0296274423599243
#  1.029729962348938 1.0298829078674316 1.03019380569458 1.030428171157837
#  1.0305688381195068 1.030670166015625 1.0308443307876587
#  1.0309332609176636 1.0310815572738647 1.0312259197235107
#  1.031326413154602 1.031493902206421 1.0317004919052124 1.0319339036941528
#  1.0324256420135498 1.0328445434570312 1.03316330909729 1.0334528684616089
#  1.0336368083953857 1.03383207321167 1.033961534500122 1.0340732336044312
#  1.0341479778289795 1.034255027770996 1.0344117879867554
#  1.0344892740249634 1.0344970226287842 -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- --]
# 1.0362949

# %% [markdown]
# ## Visual QC
#
# - Visualize the float and reference surface saturations, as well as the profiles.
# - Observe if DOXY data is set to '3' as it should be or if it is '1' or '2'.
# - Try to note cycles or other identifying features of potentially problematic profiles.

# %%
g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_initial.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figure 1: Top panel: Float oxygen percent saturation (blue line) compared to WOA percent saturation (orange line), with DOXY audit flagged cycle percent saturation (green stars, if applicable) and raw float percent saturation (orange circles). Bottom panel: calculated gains (blue dots) and flagged gains from DOXY audit (orange stars).
#
# Notes: WOA data doesn't match up very nicely in high peaks - makes sense that in-air gain is lower.

# %%
flt.reset()
g = flt.plot('qcprofiles', varlist=['DOXY', 'TEMP', 'PSAL'])
g.fig.savefig(fig_path / 'qcprofiles.png', bbox_inches='tight', dpi=250)
g = flt.plot('qcprofiles', varlist=['DOXY', 'TEMP', 'PSAL'])
g.axes[0].set_ylim((200,0))
g.fig.savefig(fig_path / 'qcprofiles_shallow.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# Figures 2,3: Profiles coloured by QC flag (1-2, green, 3, yellow, 4, red) on difference depth scales.
#
# Notes: [notes on what this figure tells you here]

# %% [markdown]
# ## Flag bad data, recalculate gain
#
# - Using the plots above (and likely some more specific plots, made on a case-by-case basis), flag bad DOXY data as 4.
# - After flagging bad data, re-clean the data and re-calculate the gains.

# %%
bad_oxygen = [] # index defining where the oxygen should be flagged as bad
flt.update_field('DOXY_QC', 4, where=bad_oxygen)
flt.update_field('DOXY_ADJUSTED_QC', 4, where=bad_oxygen)
flt.clean()
new_gains = flt.calc_gains(ref='WOA')
print(np.nanmean(new_gains))

g = flt.plot('gain', ref='WOA')
g.axes[0].set_title(f'WMO: {wmo}', loc='left', fontweight='bold')
g.axes[0].plot(flt.df.SDN.loc[flt.df.PRES < 50], flt.df.O2Sat.loc[flt.df.PRES < 50], 'o', zorder=0, alpha=0.1)
g.fig.savefig(fig_path / 'gain_final.png', bbox_inches='tight', dpi=250)
# Out:
# Calculating gains using WOA surface data and float O2 percent saturation...
# 1.0523366140696873

# %% [markdown]
# Figure x: Repeated gain plot with bad data removed.
#
# ## Update Fields and Export
#
# - DOXY should be 3 by default, but many old floats have 1 or 0. Though it will be redundant in some cases, make sure DOXY_QC is not good.
# - Apply the gain to calculate DOXY_ADJUSTED.
# - Fill in DOXY_ADJUSTED_ERROR with an appropriate fixed value.
# - Fill in DOXY_ADJUSTED_QC.
# - Make sure DOXY_ADJUSTED and DOXY_ADJUSTED_ERROR are `FillValue` wherever DOXY_ADJUSTED_QC is bad.
# - Export the D-mode files. During export, HISTORY parameters will be filled as well as SCIENTIFIC_CALIB parameters using some default structures and user info set by calling `bgc.configure.configure()`.

# %%
# make sure DOXY_QC is 3 instead of 0,1,2
flt.update_field('DOXY_QC', 3, where=flt.DOXY_QC.isin([0, 1, 2]))
# fill in DOXY_ADJUSTED_QC appropriately
# flt.update_field('DOXY_ADJUSTED_QC', flt.DOXY_QC)
# flt.update_field('DOXY_ADJUSTED_QC', 1, where=flt.DOXY_ADJUSTED_QC.isin([0, 3]))
# flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.TEMP_ADJUSTED_QC == 4)
# flt.update_field('DOXY_ADJUSTED_QC', 3, where=flt.PSAL_ADJUSTED_QC == 4)
# make sure the data is FillValues where adjusted values are still bad
flt.update_field('DOXY_ADJUSTED_QC', 4, where=flt.DOXY_ADJUSTED.isna())
flt.set_fillvalue('DOXY_ADJUSTED', where=flt.DOXY_ADJUSTED_QC == 4)
flt.set_fillvalue('DOXY_ADJUSTED_ERROR', where=flt.DOXY_ADJUSTED_QC == 4)

# %%
# export the files
comment = 'by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma'
comment += f"; Visual QC by Christopher Gordon (DFO, ORCID {bgc.config['orcid']})"
comment = comment.replace('No time response correction done;', '')
flt.export_files(data_mode='D', comment=comment, coeff='previous', equation='previous')
# Out:
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_001.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_002.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_003.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_004.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_005.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_006.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_007.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_008.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_009.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_010.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_011.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_012.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_013.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_014.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_015.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_016.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_017.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_018.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_019.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_020.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_021.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_022.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_023.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_024.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_025.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_026.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_027.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_028.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_029.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_030.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_031.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_032.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_033.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_034.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_035.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_036.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_037.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_038.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_039.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_040.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_041.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_042.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_043.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_044.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_045.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_046.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_047.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_048.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_049.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_050.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_051.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_052.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_053.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_054.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_055.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_056.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_057.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_058.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_059.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_060.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_061.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_062.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_063.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_064.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_065.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_066.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_067.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_068.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_069.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_070.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_071.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_072.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_073.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_074.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_075.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_076.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_077.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_078.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_079.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_080.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_081.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_082.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_083.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_084.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_085.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_086.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_087.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_088.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_089.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_090.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_091.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_092.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_093.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_094.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_095.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_096.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_097.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_098.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_099.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_100.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_101.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_102.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_103.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_104.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_105.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_106.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_107.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_108.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_109.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_110.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_111.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_112.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_113.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_114.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_115.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_116.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_117.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_118.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_119.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_120.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_121.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_122.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_123.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_124.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_125.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_126.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_127.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_128.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_129.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_130.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_131.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_132.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_133.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_134.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_135.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_136.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_137.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_138.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_139.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_140.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_141.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_142.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_143.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_144.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_145.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_146.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_147.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_148.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_149.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_150.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_151.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_152.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_153.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_154.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_155.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_156.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_157.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_158.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_159.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_160.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_161.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_162.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_163.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_164.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_165.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_166.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_167.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_168.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_169.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_170.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_171.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_172.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_173.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_174.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_175.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_176.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_177.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_178.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_179.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_180.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_181.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_182.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_183.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_184.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_185.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_186.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_187.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_188.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_189.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_190.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_191.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_192.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_193.nc...done
# Working on D-mode file /Users/GordonC/Documents/data/Argo/dac/meds/D/4900873/profiles/BD4900873_194.nc...done

# %%
from pathlib import Path
import pandas as pd
from netCDF4 import Dataset
import copy

loc = Path(f'/Users/GordonC/Documents/data/Argo/dac/meds/D/{wmo}/profiles/')
files = pd.read_csv(Path(f'../../../checker/summary/{wmo}/files.txt'))
varname = 'DOXY'
for fn in files.files:
    print(fn)
    nc = Dataset(loc / fn, 'r+')
    print(nc['DOXY'][:])
    flags = copy.deepcopy(nc[varname+'_QC'][:])
    flags[nc[varname][:].mask] = b'9'
    nc[varname+'_QC'][:] = flags
    if varname == 'DOXY':
        flags = copy.deepcopy(nc[varname+'_ADJUSTED_QC'][:])
        flags[nc[varname][:].mask] = b'9'
        nc[varname+'_ADJUSTED_QC'][:] = flags
    profile = copy.deepcopy(nc['PROFILE_DOXY_QC'][:])
    profile[0] = b'F' if fn == 'BD4900873_039.nc' else b'A'
    nc['PROFILE_DOXY_QC'][:] = profile
    nc.close()
# Out:
# BD4900873_039.nc
# [[322.00628662109375 492.43096923828125 107.79448699951172
#   50.82822799682617 54.58551788330078 -- 144.4772491455078
#   536.2742919921875 126.43301391601562]]
